# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5c05f555-d814-4d6e-bde4-7c3a7c28b783" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c05f555-d814-4d6e-bde4-7c3a7c28b783">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('student_performance.csv')
df.head()
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/student_performance.csv')
df.head()
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
import pandas as pd
df = pd.read_csv('student_performance.csv')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
print(df)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
import pandas as pd
data = pd.read_csv("student_performance.csv")
print(data)
data = data.drop([0,1,2,3,4])
print(data)
data.to_csv("new_file.csv",index=False)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
data = pd.read_csv("student_performance.csv")
print(data)
data = data.drop([0,1,2,3,4])
print(data)
data.to_csv("updatedfile(Aman).csv",index=False)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
import pandas as pd
data = pd.read_csv("student_performance.csv")
print(data)
mathscore = int(input("Enter Score:"))
result = data[data["math_score"] == mathscore]
print(result)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
print("department in the Given data set:")
print(df['department'].unique())
print("\n How many studnet per department:")
print(df['department'].value_counts())
# Out:
# department in the Given data set:
# ['Computer Science' 'Electronics' 'Mechanical' 'Civil']
#
#  How many studnet per department:
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
print("Gender in the Given data set:")
print(df['gender'].unique())
print("\n How many studnet per Gender:")
print(df['gender'].value_counts())
# Out:
# Gender in the Given data set:
# ['Male' 'Female']
#
#  How many studnet per department:
# gender
# Male      15
# Female    15
# Name: count, dtype: int64

# %%
print("semester in the Given data set:")
print(df['semester'].unique())
print("\n How many studnet per semester:")
print(df['semester'].value_counts())
# Out:
# semester in the Given data set:
# [2]
#
#  How many studnet per semester:
# semester
# 2    30
# Name: count, dtype: int64

# %%
print("City in the Given data set:")
print(df['city'].unique())
print("\n How many studnet per city:")
print(df['city'].value_counts())
# Out:
# City in the Given data set:
# ['Mumbai' 'Ahmedabad' 'Delhi' 'Hyderabad' 'Kochi' 'Pune' 'Bangalore'
#  'Lucknow' 'Varanasi' 'Kolkata' 'Chennai' 'Jaipur' 'Mysore' 'Thrissur'
#  'Bhopal' 'Agra' 'Patna' 'Nagpur' 'Dehradun' 'Chandigarh'
#  'Thiruvananthapuram' 'Surat' 'Allahabad' 'Kanpur' 'Indore']
#
#  How many studnet per city:
# city
# Kochi                 2
# Lucknow               2
# Thiruvananthapuram    2
# Agra                  2
# Kolkata               2
# Hyderabad             1
# Mumbai                1
# Delhi                 1
# Ahmedabad             1
# Varanasi              1
# Bangalore             1
# Pune                  1
# Jaipur                1
# Mysore                1
# Thrissur              1
# Bhopal                1
# Chennai               1
# Patna                 1
# Nagpur                1
# Dehradun              1
# Chandigarh            1
# Surat                 1
# Allahabad             1
# Kanpur                1
# Indore                1
# ...

# %%
cs_student=df[(df['city']=='Mumbai')|(df['city']=='Delhi')]
print(cs_student[['name','city','programming_score']])
# Out:
#            name    city  programming_score
# 0  Aarav Sharma  Mumbai                 91
# 2   Rohit Verma   Delhi                 55

# %%
high_attendce=df[df['attendance_percentage'] > 90]
print(f"Students with attendance greater than 90:")
print(high_attendce[['name','department','attendance_percentage']])
# Out:
# Students with attendance greater than 90:
#               name        department  attendance_percentage
# 0     Aarav Sharma  Computer Science                     92
# 3      Sneha Reddy        Mechanical                     95
# 7      Divya Singh  Computer Science                     96
# 9       Ananya Das  Computer Science                     98
# 13   Kavya Nambiar        Mechanical                     91
# 15    Ritu Agarwal       Electronics                     93
# 17  Swati Kulkarni  Computer Science                     94
# 21     Tanvi Mehta  Computer Science                     97
# 24       Amit Bose  Computer Science                     91
# 29  Akanksha Yadav  Computer Science                     95

# %%
high_attendce=df[df['attendance_percentage'] < 90]
print(f"Students with attendance lessar than 90:")
print(high_attendce[['name','department','attendance_percentage']])
# Out:
# Students with attendance lessar than 90:
#               name        department  attendance_percentage
# 1      Priya Patel  Computer Science                     87
# 2      Rohit Verma       Electronics                     78
# 5      Meera Joshi       Electronics                     72
# 6      Kiran Kumar             Civil                     85
# 8     Rahul Mishra        Mechanical                     68
# 10     Vikram Iyer       Electronics                     83
# 11     Pooja Gupta             Civil                     80
# 12      Suresh Rao  Computer Science                     88
# 14     Ajay Tiwari  Computer Science                     75
# 16    Manoj Pandey             Civil                     65
# 18  Deepak Chauhan        Mechanical                     77
# 19    Nisha Kapoor  Computer Science                     89
# 20   Harish Pillai       Electronics                     74
# 22    Sanjay Dubey             Civil                     70
# ...

# %%
df['average_score'] = df[['math_score', 'science_score', 'english_score', 'programming_score']].mean(axis=1)
lowest_performing_student = df.loc[df['average_score'].idxmin()]
print("Lowest Performing Student:")
print(f"Name: {lowest_performing_student['name']}")
print(f"Age: {lowest_performing_student['age']}")
print(f"Gender: {lowest_performing_student['gender']}")
print(f"Department: {lowest_performing_student['department']}")
print(f"Average Score: {lowest_performing_student['average_score']:.2f}")
# Out:
# Lowest Performing Student:
# Name: Manoj Pandey
# Age: 21
# Gender: Male
# Department: Civil
# Average Score: 52.50
